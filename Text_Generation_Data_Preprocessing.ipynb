# %% [markdown]
# # Text Generation task: Generate product names from description
#
# # Data Cleaning and Preprocessing

# %% [markdown]
# # Importing the libraries

# %%
# Import utils and text processing libraries
import pandas as pd
import re
import string
import os, shutil
import unicodedata

# Import library to split our dataset
from sklearn.model_selection import train_test_split

# %%
#Check the wotrking dir
# !cd
# Out:
# C:\Users\edumu\Google Drive\Projects\SpainAI NLP

# %% [markdown]
# We are going to remove the punctuations but we will keep the "." punctuation wich is necessary to work with sentences as a delimiter

# %%
punctuation = string.punctuation.replace('.', '')
print(punctuation)
# Out:
# !"#$%&'()*+,-/:;<=>?@[\]^_`{|}~

# %% [markdown]
# First, we set some global variables, including the data path and filenames.

# %%
# RUN THIS CELL When running out of Colab 
root_folder = "C:/Users/edumu/Google Drive"

# %%
# RUN THIS CELL When running ON Colab 
root_folder = '/content/drive/My Drive'

# %%
# Set the data path and filename of our dataset
data_folder_name='datasets/text_gen_product_names'
train_filename= 'train.csv'
test_filename= 'test_descriptions.csv'

data_path = os.path.abspath(os.path.join(root_folder, data_folder_name))
train_filenamepath = os.path.abspath(os.path.join(data_path, train_filename))
test_filenamepath = os.path.abspath(os.path.join(data_path, test_filename))

print('Filename: ',train_filenamepath)
datafile_type=os.path.splitext(train_filename)[1]
# Depending on the datafile we set the names of the columns to use
cols_to_use = ['name','description']
# Set the enriment variabe DATA if we need to copy the file from GCS
os.environ['DATA'] = data_path
# Out:
# Filename:  C:\Users\edumu\Google Drive\datasets\SpainAI NLP\train.csv

# %% [markdown]
# ### Loading the dataset
#
# We check if the datafile is a csv or excel file and then we load the file into a Pandas Dataframe.

# %%
# Read the csv or excel file to a dataframe
if datafile_type == '.csv':
    data = pd.read_csv(train_filenamepath, encoding='utf-8')
elif datafile_type == '.xls' or datafile_type == '.xlsx':
    # Load the data from the file system
    data = pd.read_excel(DATADIR + data_filename, encoding='utf-8')
# Show the number of examples and the first 5 records
print("Number of examples: ", len(data))
data.head(5)
# Out:
# Number of examples:  33613
#                                 name  \
# 0                 CROPPED JACKET TRF
# 1    OVERSIZED SHIRT WITH POCKET TRF
# 2             TECHNICAL TROUSERS TRF
# 3                        SHIRT DRESS
# 4  PUFF SLEEVE DRESS WITH PLEATS TRF
#
#                                          description
# 0  Jacket made of a technical fabric with texture...
# 1  Oversized long sleeve shirt with a round colla...
# 2  High-waist trousers with a matching elastic wa...
# 3  Collared dress featuring sleeves falling below...
# 4  Loose-fitting midi dress with a round neckline...

# %%
print(data['name'][50],'\n',data['description'][50],'\n')
# Out:
# SLEEVELESS KNIT TOP
#  Sleeveless knit top with a high neck. <br/><br/>HEIGHT OF MODEL: 177 cm. / 5′ 9″

# %% [markdown]
# Now we remove all the columns that are not needed in our exercise. We only save the xtext variable and the text variable. They become the text variable and summary variable.

# %%
# we are using the text variable as the summary and the ctext as the source text
dataset = data[cols_to_use].copy()
print(dataset.head(5))
# Out:
#                                 name  \
# 0                 CROPPED JACKET TRF
# 1    OVERSIZED SHIRT WITH POCKET TRF
# 2             TECHNICAL TROUSERS TRF
# 3                        SHIRT DRESS
# 4  PUFF SLEEVE DRESS WITH PLEATS TRF
#
#                                          description
# 0  Jacket made of a technical fabric with texture...
# 1  Oversized long sleeve shirt with a round colla...
# 2  High-waist trousers with a matching elastic wa...
# 3  Collared dress featuring sleeves falling below...
# 4  Loose-fitting midi dress with a round neckline...

# %%
# Check the number of rows, null values, etc
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33613 entries, 0 to 33612
# Data columns (total 2 columns):
# name           33613 non-null object
# description    33613 non-null object
# dtypes: object(2)
# memory usage: 525.3+ KB

# %% [markdown]
# Now that the text data is loaded in a dataframe we can check some basic descriptive statistics:

# %%
dataset.describe()
# Out:
#                  name                                        description
# count           33613                                              33613
# unique          23428                                              31593
# top     PRINTED DRESS  Short sleeve T-shirt with a round neckline and...
# freq               61                                                 48

# %% [markdown]
# Our feature field is the variable `description`, our source text, and there are some duplicates values in this field that we need to remove. Our dataset contains only one feature and one label, so any row with null values must be deleted.
#
# Removing the examples with null values or duplicates.

# %%
#Remove duplicates on the ctext 
#dataset.drop_duplicates(subset=["description"],inplace=True)
#Remove rows containing null values
dataset.dropna(inplace=True)
#Recreate the dataframe index
dataset.reset_index(drop=True,inplace=True)
dataset.describe()
# Out:
#                  name                                        description
# count           33613                                              33613
# unique          23428                                              31593
# top     PRINTED DRESS  Short sleeve T-shirt with a round neckline and...
# freq               61                                                 48

# %%
print(dataset['name'][50],'\n',dataset['description'][50],'\n')
# Out:
# SLEEVELESS KNIT TOP
#  Sleeveless knit top with a high neck. <br/><br/>HEIGHT OF MODEL: 177 cm. / 5′ 9″

# %% [markdown]
# ### Data cleanings and preprocess
#
# Now it is time to apply some functions for common text cleaning operations like:
#
# - Remove URLs
# - Remove html tags
# - Remove some emojis
# - Expand common contractions
# - Replace some special symbols
# - Remove punctuation
# - Remove non-character (Unicode \xFF)
# - Remove break line \n
# - Remove consecutive blanks
# - Remove mention @
# - Remove hastag #

# %%
# Create a mapping to handle contractions
contraction_mapping = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", 
                       "couldn't": "could not", "didn't": "did not",  "doesn't": "does not", "don't": "do not", "hadn't": "had not", 
                       "hasn't": "has not", "haven't": "have not", "he'd": "he would","he'll": "he will", "he's": "he is", 
                       "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",  "I'd": "I would", 
                       "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", 
                       "i'd": "i would", "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", 
                       "i've": "i have", "isn't": "is not", "it'd": "it would", "it'd've": "it would have", "it'll": "it will", 
                       "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam", "mayn't": "may not", 
                       "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have", 
                       "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have",
                       "o'clock": "of the clock", "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", 
                       "sha'n't": "shall not", "shan't've": "shall not have", "she'd": "she would", "she'd've": "she would have", 
                       "she'll": "she will", "she'll've": "she will have", "she's": "she is", "should've": "should have", 
                       "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as", 
                       "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", 
                       "there'd": "there would", "there'd've": "there would have", "there's": "there is", "here's": "here is",
                       "they'd": "they would", "they'd've": "they would have", "they'll": "they will", "they'll've": "they will have", 
                       "they're": "they are", "they've": "they have", "to've": "to have", "wasn't": "was not", "we'd": "we would", 
                       "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are", "we've": "we have", 
                       "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",  
                       "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", 
                       "where's": "where is", "where've": "where have", "who'll": "who will", "who'll've": "who will have", 
                       "who's": "who is", "who've": "who have", "why's": "why is", "why've": "why have", "will've": "will have", 
                       "won't": "will not", "won't've": "will not have", "would've": "would have", "wouldn't": "would not", 
                       "wouldn't've": "would not have", "y'all": "you all", "y'all'd": "you all would","y'all'd've": "you all would have",
                       "y'all're": "you all are","y'all've": "you all have","you'd": "you would", "you'd've": "you would have", 
                       "you'll": "you will", "you'll've": "you will have", "you're": "you are", "you've": "you have" }

def expand_contractions(text, mapping):
    ''' Expand the contractions (some well-known of them) in a text'''
    specials = ["’", "‘", "´", "`"]
    for s in specials:
        text = text.replace(s, "'")
    text = ' '.join([mapping[t] if t in mapping else t for t in text.split(" ")])
    return text

# %%
special_mapping = {"‘": "'", "₹": "e", "´": "'", "°": "", "€": "e", "™": "tm", "√": " sqrt ", "×": "x", "²": "2", "—": "-", "–": "-", 
                 "’": "'", "_": "-", "`": "'", '“': '"', '”': '"', '“': '"', "£": "e", '∞': 'infinity', 'θ': 'theta', '÷': '/', 
                 'α': 'alpha', '•': '.', 'à': 'a', '−': '-', 'β': 'beta', '∅': '', '³': '3', 'π': 'pi', 'Â':'', 'Ł':'',
                'Ă': '', '&#39;':"'", '&#34;':'"', '&amp;':'&'}

def remove_URL(text):
    ''' Remove URLs from the text'''
    url = re.compile(r'https?://\S+|www\.\S+')
    return url.sub(r'',text)

# Remove html tag
def remove_html(text):
    ''' Remove HTML tags from the text'''
    html=re.compile(r'<.*?>')
    return html.sub(r'',text)

def remove_mention(text):
    ''' Remove mentions from the text'''
    url = re.compile(r'@\S*')
    return url.sub(r'',text)

def remove_mult_spaces(text):
    ''' Reduce multispace to one single space'''
    re_mult_space = re.compile(r"  *") # replace multiple spaces with just one
    return re_mult_space.sub(r' ', text)

def remove_non_character(text):
    ''' Remove some non alphanumeric characters'''
    url = re.compile(r'\x89\S*|\x9b\S*|\x92\S*|x93\S*|\x8a\S*|\x8f\S*|\x9d\S*|\x8c\S*|\x91\S*|\x87\S*|\x88\S*|\x82\S*')
    #url = re.compile(r'\x\d+\S*')
    return url.sub(r'',text)

def remove_punctuation(text, punctuation):
    ''' Remove punctuation from the text'''
    table=str.maketrans('','',punctuation)
    return text.translate(table)

def remove_emoji(text):
    ''' Remove emojis from the text'''
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)

def remove_CTL(text):
    ''' Remove end of line from the text'''
    url = re.compile(r'\n')
    return url.sub(r' ',text)

def remove_hashtag(text):
    ''' Remove hashtags from the text'''
    url = re.compile(r'#\S*')
    return url.sub(r'',text)

def unicode_to_ascii(s):
    ''' Transform unicode symbols to ascii'''
    return ''.join(c for c in unicodedata.normalize('NFD', s)
                    if unicodedata.category(c) != 'Mn')

def replace_mapping(text, mapping):
    ''' Replace some special characters to an appropiate substitute'''
    for p in mapping:
        text = text.replace(p, mapping[p])

    return text

# %% [markdown]
# We will create a function that will apply all the cleaning functions to a pandas column, using the apply method.

# %%
def clean_text(text):
    ''' Clean the input text using common techniques'''
    new_text = text
    #new_text=new_text.apply(lambda x : unicode_to_ascii(x))
    new_text=new_text.apply(lambda x : replace_mapping(x, special_mapping))
    new_text=new_text.apply(lambda x : remove_URL(x))
    new_text=new_text.apply(lambda x : remove_html(x))
    new_text=new_text.apply(lambda x : remove_emoji(x))
    new_text=new_text.apply(lambda x : remove_CTL(x))
    new_text=new_text.apply(lambda x : expand_contractions(x,contraction_mapping))
    new_text=new_text.apply(lambda x : remove_non_character(x))
    new_text=new_text.apply(lambda x : remove_mention(x))
    new_text=new_text.apply(lambda x : remove_hashtag(x))
    #new_text=new_text.apply(lambda x : remove_punctuation(x, punctuation))
    new_text=new_text.apply(lambda x : remove_mult_spaces(x))
    return new_text

# %% [markdown]
# ## Tokenize and apply more complex preprocessing task
# Next step, Tokenize or split our text into tokens or words.
#
# **Tokenization**: Given a character sequence and a defined document unit, tokenization is the task of chopping it up into pieces, called tokens , perhaps at the same time throwing away certain characters, such as punctuation. A token is an instance of a sequence of characters in some particular document that are grouped together as a useful semantic unit for processing. A type is the class of all tokens containing the same character sequence*.
#
# These tokens will be our working unit. Then we can apply some preprocessing steps depending on the task:
#
#    - Lowercase
#    - Remove very short tokens
#    - Remove stop-words
#    - Apply steeming and lemmatization

# %%
#Parameters to apply to the cleaing process
# If stopwords_file is defined then we take the stop words list from this file, if not we use the stopwords from NLTK
stopw= True
#stopwords_file='NLP_short_stopwords.txt'
stopwords_file=None
# Transform to lowercase
lowercase = True
# Set min length of a token
min_length = 2
# Set if we want to apply a lemmatizer or stemmer
lemmatize = False
stemming=False
# Remove punctuation
del_punct = True
# Remove digits
del_digits = False

# %% [markdown]
# ### Stopwords
#
# Sometimes, some extremely common words which would appear to be of little value in helping select documents matching a user need are excluded from the vocabulary entirely. These words are called stop words . The general strategy for determining a stop list is to sort the terms by collection frequency (the total number of times each term appears in the document collection), and then to take the most frequent terms. Or you can use some predefined lists included in some NLP libraries like NLTK.
# In my experience, and depending on our problem, some of this lists of stop words are too extensive, removing too much words. Sometimes you can create an specific list of words, based on the language of your problem.
#
# But removing stopwords in natural language generating tasks is not a good choice, these words have no significance but they are essential to generate understandable and grammatically correct text. But in text classification problems we can ignore the stop words to force the algorithm to focus on more relevant words.
#
# Define our own stopword list or if not we can use the NLTK stopwords for english.

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('punkt')

if stopwords_file!=None:
    stop_words = set(w.rstrip() for w in open(stopwords_file))
else:
    stop_words = set(stopwords.words('english'))

def remove_stopwords(text):
    ''' Remove stopwords from the text'''
    w=set(text.split())-stop_words
    return ' '.join(w)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\edumu\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ### Lemmatizer and Stemmer
#
# Stemming and lemmatization are techniques "*to group together the inflected forms of a word so they can be analysed as a single item*", Wikipedia. So words with a similar root and meaning are considered as a unique word, optimizing the learning process.
#
# Stemming and Lemmatization both generate the root form of the inflected words. The difference is that stem might produce not an actual word whereas, lemma is an actual language word. Stemming follows an algorithm with steps to perform on the words which makes it faster. Whereas, in lemmatization, you used WordNet corpus and a corpus for stop words as well to produce lemma which makes it slower than stemming. You also had to define a parts-of-speech to obtain the correct lemma.
#
# We will use a WordNetLemmatizer and a PorterStemmer, both are frequent options.

# %%
# Define Lemmatizer object
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()

# Define the Porter Stemmer object
from nltk.stem import PorterStemmer
wordnet_stemmer = PorterStemmer()

# %% [markdown]
# ### Define the tokenizer

# %%
def my_tokenizer(s):
    ''' Apply the tokenization method to the input string s.
        We will apply, based on the setup, lowercase, remove punctuation,remove digits, 
        remove stopwords, apply stemming, apply lemmatization and remove tokens with ocurrencies
        below a minimum defined.
    '''
    if lowercase:
        s = s.lower() # downcase
    if del_punct:
        s = remove_punctuation(s, punctuation) # Remove punctuation

    if del_digits:
        s = remove_digits(s)  # Remove digits

    tokens = word_tokenize(s) # split string into words (tokens)

    tokens = [t for t in tokens if len(t) > min_length or t in string.punctuation] # remove short words, they're probably not useful

    if stopw:
        tokens = [t for t in tokens if t not in stop_words] # remove stopwords

    if stemming:
        tokens = [wordnet_stemmer.stem(t) for t in tokens]  # Apply stemming 
        
    if lemmatize:
        tokens = [wordnet_lemmatizer.lemmatize(t) for t in tokens] # Lemmatize, put words into base form
        
    return tokens

# %%
len(dataset['description']),len(dataset['name'] )
# Out:
# (33613, 33613)

# %% [markdown]
# Now we can start the cleaning process on our dataset

# %%
# Apply the cleaning functions to the source text and summary
data_text = clean_text(dataset['description'])
data_headlines = clean_text(dataset['name'])

# %%
#Checking the results
len(data_text), len(data_headlines)
# Out:
# (33613, 33613)

# %%
data_text[50]
# Out:
# 'Sleeveless knit top with a high neck. HEIGHT OF MODEL: 177 cm. / 5′ 9″'

# %%
# Save the cleaned and tokenize text in the dataframe
dataset['description']=data_text
dataset['name']=data_headlines

# %%
# Apply cleaning based on the tokenizer defined and parameters
def tokenize_and_string(sentences):
    ''' Tokenize the sentences, apply more cleaning steps
        Input: 
        - sentences: list of string, sentences of the text
        Output:
        - sentence2token: list of tokens or words, the tokens in the ever sentence
        - token2sent: list of string, the list of sentences
    '''
    # Tokenize and clean every text 
    sentence2token = [my_tokenizer(sent) for sent in sentences]
    # Convert tokens to a string
    token2sent= [' '.join(sent) for sent in sentence2token]
    
    return sentence2token,token2sent

# %%
# Tokenize the text in our dataset
_,cleaned_text=tokenize_and_string(data_text)
_,cleaned_headlines=tokenize_and_string(data_headlines)

# %% [markdown]
# Lets show some examples with our original text and the cleaned one

# %%
dataset['description'][50], cleaned_text[50]
# Out:
# ('Sleeveless knit top with a high neck. HEIGHT OF MODEL: 177 cm. / 5′ 9″',
#  'sleeveless knit top high neck . height model 177 .')

# %%
# Save the cleaned and tokenize text in the dataframe
dataset['description']=cleaned_text
dataset['name']=cleaned_headlines

# %% [markdown]
# ## Save the data preprocessed and cleaned
#
# We need to create a file for training our model and a different file for evaluation purpouses. This is very important in machine learning to simulate as much as possible the production enviroment were new and unseen examples will be received or feeded to our algorithm.

# %% [markdown]
# The traning dataset will contain 85% of the examples and the remaning will be included in the test dataset.

# %%
# Set the percentage of rows to keep in the training dataset
train_pct=0.85
# Shuffle the whole dataframe
dataset = dataset.sample(frac=1, random_state=42).reset_index(drop=True)
#Define the size of the training dataset
training_size = int(len(data)*train_pct)
print('Training size: ', training_size)

# Create a file with the whole dataset cleaned
dataset.to_csv(data_path +'\\cl_stopw_'+os.path.splitext(train_filename)[0]+'.csv', encoding='utf-8', index=False)
#Create a file with the training dataset
dataset.iloc[:training_size,:].to_csv(data_path +'\\cl_stopw_train_'+os.path.splitext(train_filename)[0]+'.csv', 
                                      encoding='utf-8',index=False)
#Create a file with the test dataset
dataset.iloc[training_size:,:].to_csv(data_path +'\\cl_stopw_valid_'+os.path.splitext(train_filename)[0]+'.csv', 
                                      encoding='utf-8', index=False)
# Out:
# Training size:  28571

# %% [markdown]
# Save the train and validation dataset to GS

# %% [markdown]
# # Preprocess the test file

# %%
# Read the csv or excel file to a dataframe
if datafile_type == '.csv':
    data = pd.read_csv(test_filenamepath)
elif datafile_type == '.xls' or datafile_type == '.xlsx':
    # Load the data from the file system
    data = pd.read_excel(DATADIR + data_filename, encoding='utf-8')
# Show the number of examples and the first 5 records
print("Number of examples: ", len(data))
print('Num Examples: ',len(data))
print('Null Values\n', data.isna().sum())
data.head(5)
# Out:
# Number of examples:  1441
# Num Examples:  1441
# Null Values
#  description    0
# dtype: int64
#                                          description
# 0  Knit midi dress with a V-neckline, straps and ...
# 1  Loose-fitting dress with a round neckline, lon...
# 2  Nautical cap with peak.<br/><br/>This item mus...
# 3  Nautical cap with peak. Adjustable inner strap...
# 4  Nautical cap with side button detail.<br/><br/...

# %%
# Apply the cleaning functions to the source text and summary
data_text = clean_text(data['description'])

# %%
data_text
# Out:
# 0       Knit midi dress with a V-neckline, straps and ...
# 1       Loose-fitting dress with a round neckline, lon...
# 2       Nautical cap with peak.This item must be retur...
# 3       Nautical cap with peak. Adjustable inner strap...
# 4       Nautical cap with side button detail.This item...
#                               ...
# 1436    Striped print cotton cushion cover. Cushion fi...
# 1437         Rectangular cushion featuring a gnome print.
# 1438    Cotton jersey eye mask featuring an elastic ba...
# 1439    Padded chipboard hanger featuring an iron hook...
# 1440    Iron hanger suitable for hanging all kinds of ...
# Name: description, Length: 1441, dtype: object

# %%
# Tokenize the text in our dataset
_,cleaned_text=tokenize_and_string(data_text)

# %%
cleaned_text
# Out:
# ['knit midi dress vneckline straps matching lace detail.height model 177 . 69.6″',
#  'loosefitting dress round neckline long sleeves pleat details buttoned opening back.height model 177 69.6″',
#  'nautical cap peak.this item must returned original cardboard packaging intact .',
#  'nautical cap peak . adjustable inner strap detail .',
#  'nautical cap side button detail.this item must returned original cardboard packaging intact .',
#  'faded short sleeve tshirt round neckline front print.due dyeing process print tshirt unique may differ shown photo.height model 177 . 69.6″',
#  'coat round collar long sleeves . featuring front welt pockets faux suede interior button fastening front . height model 177 . 69.6″',
#  'ripped tshirt . round neck short sleevesheight model 176',
#  'fitted top made polyamide blend . features wide straps chest reinforcement.model height 178',
#  'fitted top made polyamide blend . features wide straps chest reinforcement.model height 177 69.6″',
#  'fitted top made polyamide blend . features wide straps chest reinforcement.height model 178 . 10″',
#  'fitted top made polyamide blend . features round neckline straps.model height 178',
#  'fitted vest top polyamide blend . featuring round neckline straps.height model 177 .',
#  'fitted top made polyamide blend . features round neckline straps.height model 178 . 10″',
#  'fitted top polyamide blend . featuring wide straps chest reinforcement.height model 177 .',
#  'sleeveless dress vneck asymmetric front ruffle patch pockets . features frayed trims shoulders sleeves hem.height model 178 . 70.0″',
#  'round neck sweater long sleeves contrast side stripes ribbed trims.height model 189 size',
#  'bucket hat band detail .',
#  'loosefitting fine knit round neck sweater long sleeves ribbed trims.height model 189 size',
#  'loosefitting vneck knit sweater long sleeves ribbed trims.height model 189 . 74.4″',
#  'loosefitting knit turtleneck sweater long sleeves ribbed trims.height model 189 74.4″',
#  'loosefitting knit sweater high neck long sleeves ribbed trims.height model 189 . size',
#  'straight fit jacket removable faux fur collar long sleeves buttoned cuffs . featuring contrast padded interior chest flap pockets welt pockets hip . zipup front hidden placket metal buttons.height model 189 . 74.4″',
#  'straight cut coat high collar long sleeves . features welt pockets front inner pocket detail vent centre back front button fastening placket . height model 189 . 74.4″',
#  'coat featuring high collar matching removable interior long sleeves front flap pockets inside pocket detail vent centre back . button fastening front.height model 189 . 74.4″',
#  'straight cut coat high collar long sleeves . features welt pockets front inner pocket detail vent centre back front button fastening.height model 189 size eur',
#  'straight fit coat raised lapel collar long sleeves . featuring welt pockets front inside pocket detail centre back vent front button fastening.height model 189 . 74.4″',
#  'straight fit tshirt featuring ribbed round neckline piping short sleeves.height model 189 . 74.4″',
#  'short sleeve tshirt straight fit ribbed vneck.height model 189 . size',
#  'short sleeve tshirt round neckline.due dyeing process print tshirt unique may differ shown photo.height model 177 . 69.6″',
#  'long sleeve tshirt round neckline.height model 177 .',
#  'ribbed beanie featuring turnup brim label appliqué slogan.this item smaller fit usual .',
#  'long sleeve knit sweater round neckline . featuring side vents hem ribbed trims.model height 177',
#  'long sleeve knit sweater round neckline . featuring side vents hem ribbed trims.height model 177 .',
#  'stretch belt golden buckle . fastening metal hook.this item must returned original cardboard packaging intact .',
#  'wide belt metal double buckle metal chain detail .',
#  'trousers elastic waistband adjustable drawstring slogan print front pockets .',
#  'trousers elastic waistband adjustable drawstrings slogan print front pockets .',
#  'round neck tshirt short turnup sleeves.height model 177 .',
#  'highwaist trousers side pockets false rear welt pockets . front fastening zip fly metal hook .',
#  'short dress round neckline puff sleeves falling elbow inseam side pockets lining buttoned opening back.height model 177 . 69.6″',
#  'loosefitting jumpsuit round neckline long sleeves . featuring side pockets hidden inseam elastic inner waistband front gathered detail contrast belt appliqué buttoned opening back . height model 177 . 69.6″',
#  'pack fujifilm instax mini camera three packs camera film 3x10.the product must returned original packaging .',
#  'dress asymmetric neckline one short ruffled sleeve . featuring contrast belt appliqué metal buckle invisible side zip fastening . height model 177 . 69.6″',
#  'long sleeve jacket lapel collar . featuring front zip pockets faux fur lining detail belt metal buckle metal zipup fastening front . height model 177 . 69.6″',
#  'round neck jacket long sleeves shoulder pads . flared hem . front zip fastening.height model 178 . 10″',
#  'knit henley sweater long sleeves button placket chest pocket .',
#  'collared long sleeve jacket . featuring bejewelled fringe appliqués frayed trims asymmetric hem snapbutton fastening front . height model 177 .',
#  'vneck dress long sleeves . featuring matching belt detail buckle front patch pockets front button fastening.height model 177 .',
#  'leggings elastic waistband . join lifecare fiber least ecologically grown cotton . ecologically grown cotton produced using practices help protect biodiversity crop rotation use natural fertilisers .',
#  'long sleeve knit sweater round neckline ribbed trims.height model 189 . 74.4″',
#  'sweater made spun wool blend . featuring round neckline long sleeves ribbed trims.height model 189 74.4″ size eur',
#  'blazer lapel collar long sleeves decorative buttons cuffs . featuring chest welt pocket flap hip pockets inside pockets double back vent front button fastening.height model 189 . 74.4″',
#  '80s skinny bering blue.faded mid waist skinny jeans fivepocket design zip fly metal top button fastening . height model 177 .',
#  'round neck tshirt featuring short sleeves asymmetric hem.height model 178 .',
#  'short sleeve tshirt round neckline asymmetric hem.model height 177',
#  'short sleeve tshirt featuring round neckline asymmetrical hem.height model 178 . 10″',
#  'short sleeve tshirt featuring round neckline asymmetrical hem.care fiber ecologically grown cotton . ecologically grown cotton produced using practices help protect biodiversity crop rotation use natural fertilisers.height model 178 .',
#  'short sleeve tshirt round neckline.height model . 177 69.6″',
#  'large hoop earrings . pushback closure.this item must returned original cardboard packaging intact .',
#  'pack pairs differentsized hoop earrings . pushback clip closure.this item must returned original cardboard packaging intact .',
#  'textured scarf fringed edges.measurements 29.5″ 200 78.7″this item must returned original cardboard packaging intact .',
#  'pleated skirt elastic waistband.model height 177',
#  'short sleeve tshirt vneckline.model height 177',
#  'short sleeve tshirt vneckline.height model 177 .',
#  'vneck tshirt short sleeves.height model 178 . 10″',
#  'top round neckline short sleeves . features contrasting fabric ruffle hem side vents button fastening back.height model 178 . 70.0″',
#  'round earrings fabric . screwback pushback closure.this item must returned original cardboard packaging intact .',
#  'collared jumpsuit featuring long sleeves front pockets rear patch pockets elastic waist matching belt buckle metal zip fastening hidden placket.height model 177 .',
#  'straight fit sweater round neckline long sleeves . height model 189 . 74.4″',
#  'short sleeve tshirt round neckline.height model 177 . 69.6″',
#  'halter neck bodysuit snapbutton fastening bottom.model height 177 69.6″',
#  'short sleeve tshirt round neckline contrast front print detail . height model 177 .',
#  'jacket featuring elastic round collar long sleeves elastic cuffs . adjustable drawstring hem side pockets zipup front.height model 176 . 69.2″',
#  'trench coat featuring lapel collar long sleeves adjustable buckles . front welt pockets matching belt detail back vent hem doublebreasted button fastening.height model 177 . 69.6″',
#  'tailored jacket featuring high collar detachable adjustable drawstring hood long sleeves inseam front zip pockets metal zipup fastening front.height model 177 69.6″',
#  'long sleeve vneck sweater.height model 177',
#  'long sleeve vneck sweater.model height 177',
#  'plush jersey jogging trousers elastic waistband adjustable drawstrings . featuring front pockets back pocket snoopy peanuts print cuffed hems .',
#  'slim fit jeans fivepocket design . featuring faded effect zip fly metal top button fastening.height model 189 . 74.4″',
#  'round neck top long contrast pleated sleeves elastic cuffs . bow detail sleeves.height model 177 . 69.6″',
#  'stretch poplin shirt super slim fit . classic collar model long sleeves buttonup front.height model 189 . size',
#  'super slim fit shirt stretch fabric featuring regular collar long sleeves buttoned cuffs buttonup front . height model 189 size',
#  'slot collar dress vneckline adjustable cord . featuring puff sleeves reach elbow contrast embroidery details contrast tassels front . height model 177 .',
#  'puffer jacket long fit high collar long cuffed sleeves . featuring hood rubberised label appliqué slogan print zipup front snapbutton placket front pockets side vents uneven hem .',
#  'knit sweater featuring high neck long sleeves decorative metal buttons ribbed trims . height model 177 .',
#  'blazer linen blend fabric notched lapel collar long sleeves decorative buttons cuffs . featuring welt pockets chest hip back vent front button fastening.height model 189 . 74.4″',
#  'slim fit trousers linen blend fabric . featuring front pockets jetted back pockets zip fly top button fastening.height model 189 . 74.4″',
#  'long sleeve knit sweater wool blend . featuring high neck side vents hem . height model 177 . 69.6″',
#  'carrycot baby wrap hood side zip fastening . featuring allover star print faux fur lining .',
#  'coat featuring high collar matching removable interior collar long sleeves front welt pockets inside pocket detail vent centre back zipup fastening hidden snapbutton placket.height model 189 . 74.4″',
#  'cropped slim fit trousers . featuring front pockets rear jetted pockets turnup hems zip fly top button fastening.model height 189 74.4″',
#  'high waist revolve black.skinny mid waist jeans five pockets fadedeffect seams metal zip top button fastening front.sophisticated range combines supersoft innovative fabrics designs flatter figure . comfort elegance combined . model height 179',
#  'high waist revolve black.highwaist skinny jeans five pockets . featuring fadedeffect seams . zip fly metal top button fastening.sophisticated range combines super soft innovative fabrics designs flatter silhouette . comfortable elegant . height model 179 70.4″',
#  'high waist revolve black.skinny mid waist jeans five pockets fadedeffect seams metal zip top button fastening front.sophisticated range combines supersoft innovative fabrics designs flatter figure . comfort elegance combined . height model 179 . 10″',
#  'round neck tshirt long sleeves front print slogan back .',
#  'long sleeve dress surplice vneckline . featuring elastic inner waist contrast sequin appliqués . height model 177 . 69.6″',
#  'nautical cap peak.this item must returned original cardboard packaging intact .',
#  'midrise asymmetric skirt falling knee zip button fastening front . features front pocket back pockets belt loops along waistband . height model 181 . 71.2″',
#  'coat high collar contrast interior collar . featuring long sleeves front welt pockets inside pocket vent centre back front zip fastening snapbutton placket.height model 189 . 74.4″',
#  'round neck sweater long sleeves.height model 177 . 69.6″',
#  'bermuda shorts made textured fabric . featuring front pockets back welt pockets zip fly top button fastening . height model 189 . 74.4″',
#  'flowing aline dress vneck short full sleeves . featuring elastic waist button fastening front.height model 177 .',
#  'parka contrast faux shearling lining . featuring high collar adjustable hood long sleeves adjustable tabs cuffs flap pockets chest side pockets hip inside pocket adjustable drawstring hem zipup fastening concealed button placket.height model 189 . 74.4″',
#  'regular fit shirt featuring buttondown collar long cuffed sleeves chest patch pocket buttonup front.height model 189 . 74.4″',
#  'loosefitting trousers elastic waistband adjustable ribbons . featuring front patch pockets side vents hems.model height 177',
#  'high waist leggings elastic drawstring waistband patch pockets flaps legs.height model 177 .',
#  'flowing blouse high neck long full sleeves . featuring contrast fabric lining buttoned opening back . height model 177 . 69.6″',
#  'silk jacquard skinny tie diagonal texture .',
#  'high waist skinny sunrise blue.faded highwaist skinny jeans featuring fivepocket design frayed hems . metal zip fly top button fastening front . height model 177',
#  'high waist revolve black.skinny high waist trousers five pockets.sophisticated range combines supersoft innovative fabrics designs flatter figure . comfort elegance combined . height model 179 . 10″',
#  'coat made wool blend . featuring lapel collar long sleeves front patch pockets back vent doublebreasted button fastening front.height model 177 . 69.6″',
#  'regular fit shirt made linen blend . featuring standup collar long sleeves inside tabs buttonup front.height model 189 size',
#  'collared shirt long sleeves contrast trims sides buttonup front hidden placket.height model 176 . 69.2″',
#  'trousers elastic waistband shiny thread bow appliqué . pleats front pockets . turnup hems .',
#  'trousers elastic waistband metallic thread bow appliqué . feature pleats pockets front turnup hems .',
#  'long sleeve jacket shawl collar pronounced shoulders . featuring frayed trims front flap pockets doublebreasted front contrast buttons.height model 177',
#  'mid waist trousers flared hems featuring sequin appliqués front zip inside button metal hook fastening.height model 177 . 69.6″',
#  'highrise trousers . zip fly metal hook fastening.height model 177 . 69.6″',
#  'jumpsuit lapel collar vneck long sleeves . featuring side welt pockets back patch pockets flap elastic inner waistband belt appliqué matching fabric front button fastening hidden placket . height model 177 . 69.6″',
#  'knit dress high neck short full sleeves . featuring contrast fabric detail ruffled hem . height model 177 69.6″',
#  'puffer jacket high collar hood long sleeves . featuring hip pockets thermosealed zips inside pockets elastic adjustable hem thermosealed zipup front.height model 189 . 74.4″',
#  'faux leather jacket round neckline long sleeves . features two front zip pockets lining inside snapbutton pocket zipup front ribbed trims.height model 189 . size',
#  'collared overshirt long rolledup sleeves . featuring front welt pockets chest patch pockets flaps frayed hem buttonup fastening . height model 177 . 69.6″',
#  'high waist trousers front pockets false rear jetted pockets . featuring belt fabric covered buckle fastening metal hook inside button zip.height model 177 69.6″',
#  'high waist trousers lined buckled belt around waist . featuring front pockets false welt pockets back front pleats metal hook inside button zip fastening front.model height 178',
#  'parka made waterrepellent fabric . padded interior thermore® thermal insulation helps retain body heat . lightweight breathable easy clean . featuring high collar hidden hood long sleeves ribbed inner cuffs . patch pockets flaps chest hip inside pocket detail . zipup front closure hidden snapbutton placket.height model 189 . 74.4″',
#  'pack three pairs briefs elastic waistband assorted panda prints .',
#  'loosefitting coat lapel collar long sleeves . featuring front flap pockets button fastening front . height model 177 . 69.6″',
#  'round neck dress long sleeves elastic cuffs . featuring fabric lace top matching pleated hem matching velvet tape appliqués inseam back zip fastening . height model 177 69.6″',
#  'oversized collared shirt long sleeves . featuring chest patch pocket side vents hem buttonup front . height model 177 . 69.6″',
#  'tshirt round neckline short sleeves . featuring front print feather appliqués .',
#  'tshirt round neckline short sleeves . featuring front print feather appliqués .',
#  'short sleeve tshirt round neckline contrast front print.height model 177 . 69.6″',
#  '80s high waist old blue.high waist skinny jeans fivepocket design . featuring faded effect ripped detailing front frayed hems zip fly metal top button fastening . height model 177 .',
#  'knit vneck dress short full sleeves elastic waist ruffle trims hem . height model 177 . 69.6″',
#  'chino trousers adjustable interior waistband top button fastening . feature front back pockets turnup hems metal lobster clasp detail multicoloured cord .',
#  'burgundy high heel boots . leather upper animal print metallic finish . overtheknee slouchy design . inside zip.covered block heel.heel height . 3.9″calf width . 9.4″',
#  'giraffeshaped crossbody bag . zip closure mini giraffeshaped decorative accessory . shoulder strap . fabric lining.height length width . 9.8 4.7 3.9″',
#  'midheel ankle boots available red black . black model features animal print upper . lined stiletto mid heel . pointed toe . zip fastening front.heel height 6.7 . 2.6″',
#  'black highheel ankle boots . mesh upper shiny detailing . covered stiletto heel . pointed toe . zip closure back.heel height . 3.9″',
#  'black highheel shoes . snakeskineffect animal print . asymmetricallyshaped upper front . stiletto heels . heel height 9.5 . 3.7″',
#  'silver highheel shoes . combination materials upper transparent vinyl detail . lined stiletto heel . pointed toe . heel height . 3.9″',
#  'sandcoloured leather heeled shoes . suede upper . metallic stiletto heels . pointed toes . heel height 9.5 . 3.7″',
#  'midheel mules available beige red . vinyl upper contrast materials . faux patent finish block heels contrast colour . pointed toe . heel height 7.2 . 2.8″',
#  'highheel mules available fuchsia black . suede upper . heels metal section base lined leather . pointed toes . heel height . 2.7″',
#  'black highheel sandals . asymmetric upper rhinestoneappliquéd strap across front . covered stiletto heel . square toe . buckled ankle strap fastening.heel height . 3.9″',
#  'black high heel sandals . upper sole heel velvet raised detail . front knot . back strap . lined block heel platform . square toe . buckled ankle strap fastening.airfit® . flexible technical latex foam insole designed offer greater comfort.heel height . 4.7″',
#  'leather mini wedges available black tan . leather upper . strap across front . wide ankle strap . wedge jutelined heel . track sole . maxi metal buckled fastening ankle strap . wedge height . 1.9″',
#  'black leather highheel sandals . leather upper . diamanté detail front strap ankle strap . lined stiletto heels . square toe . zip closure back . blue collection . premium leather trims aegean blue soles metal emblem . heel height . 4.3″',
#  'beige high heel mules . made natural materials . frayed knot detail front . round block heels lined jute . heel height 7.4 . 2.9″',
#  'midheel mules thin asymmetric straps front . thin strap across instep . covered mid block heel . heel height 7.8 . 3.0″',
#  'red heeled sandals . combined plain plaited strap upper . lined medium heel . ankle tie faux wooden bead detail . heel height 6.5 . 2.5″',
#  'piggyshaped bad . zip closure sheepshaped decorative accessory . printed 100 cotton lined interior.height length width . 2.7 6.2 3.1″',
#  'white sneakers . combination finishes upper . back pull tab . chunky soles . sole height . 2.3″',
#  '100 cotton lunch bag . zip closure . top handles . height length width 19.5 11.50 . 6.2 7.6 4.5″',
#  'leather loafers available black burgundy . leather upper . penny strap instep . gathered seam detail toe.heel height 2.3 . 0.9″',
#  '100 cotton backpack . faux shearling effect decorative ears . main compartment additional front pocket zip closure . handle adjustable padded shoulder straps.height length width . 15.7 13.3 3.9″',
#  'flat shoes available different colours black beige . diecut upper . sole height 1.8 . 0.7″',
#  'flat slingback shoes available different colours ecru copper sea green . cagestyle straps upper . pointed toe . sole height 1.5 . 0.5″',
#  'faux fur crossbody bag shape dog . compartment zip closure . shoulder strap.height length width . 3.1 9.8 3.1″',
#  'black leather heeled sandals . animal print leather upper . metal ring front . lined kitten heel . blue collection . premium leather trims aegean blue soles metal emblem special packaging . heel height 4.4 .',
#  'black leather flat sandals . leather upper . cowboystyle metal buckles . front strap buckle detail . crisscross ankle straps buckle fastening . sole height . 1.1″',
#  'leather highheel ankle boots different colours black white . leather upper contrast piping topstitching . leg cutout front slit detail . geometric cowboy heel . pointed toe . pull tab sides . heel height . 3.1″',
#  'leather heeled boots available different colours burgundy snakeskin print . leather upper animal print . lined stiletto heel . pointed toe.heel height 8.5 . 3.3″calf width 19.5 . 7.6″',
#  'highheel boots available black tan . leather upper . inner zip . covered block high heel . platform sole.heel height . 4.3″',
#  'brown leather ankle boots split suede finish . lowcut fit . decorative seams upper . two elastic side panels back pull tab slipping ease . rounded toes . leather insoles . black soles .',
#  'leather laceup desert boots . available tan black . facing two pairs eyelets . soft construction vintage look . round toe . leather insole .',
#  'black midheel ankle boots . round block heel . gold zip closure back . heel height . 2.3″',
#  'black laceless hightop sneakers made technical fabric . onepiece upper . sockstyle design . decorative plastic piece heel . maxi soles rounded pieces sole . red detail back outsole .',
#  'laceup hightop sneakers . black contrast camouflage animal print mock croc details . eighteyelet facing . padded ankles . back pull tab . goldtoned piece welt . chunky black zara light sole guarantees maximum lightness comfort .',
#  'black leather highheel ankle boots . split suede upper . block heel . inside zip closure . heel height 7.5 . 2.9″',
#  'black highheel ankle boots . upper contrast materials . elastic side panels . lined block heel . pull tab back . track sole . heel height . 4.3″',
#  'black heeled ankle boots . stretch upper . stiletto heels . inside zip closure . heel height . 3.9″',
#  'laceless hightop sneakers technical fabric . sockstyle design . upper cut single piece mesh technical fabric . thermoformed insole greater comfort . black spliteffect sole rubber technical piece gold .',
#  'snakeskin print leather heeled ankle boots . soft leather animal print upper . cowboy heel . pointed toe . side pull tabs.heel height 5.5 . 2.1″',
#  'high heel shoes available black mustard yellow . vamp . block heel . pointed toe.heel height . 3.1″',
#  'black laceup sneakers . sixeyelet facing . upper combination colours materials including mesh rubberised details . sockstyle design . includes pull tab front heel cap . twotone chunky sole .',
#  'neon lime green monochrome laceup sneakers . eighteyelet facing . technical piece back . upper cut single piece different textures fabric .',
#  'black laceup sneakers eyelets eight laces . featuring overlaid patterns upper micro perforated detail instep .',
#  'white plimsolls . seveneyelet facing pair metal eyelets top . blue heel tab . white blue red tape detail tongue .',
#  'highheel shoes available black beige red . contrast materials upper transparent vinyl detail . stiletto heel . pointed toe . heel height 10.5 . 4.1″',
#  'white sneakers . sixeyelet facing . black trims side heel embossed detail . black contrast heel counter . chunky sole .',
#  'white leather plimsolls . seveneyelet facing . thermoformed insoles greater comfort . grey heel tabs . white soles .',
#  'black leather plimsolls . seveneyelet facing . black split suede heel tab . thermoformed insoles greater comfort . white soles .',
#  'white slingback heels . back strap . kitten heel . pointed toe . heel height 6.2 . 2.4″',
#  'leather high heel shoes available different colours black snakeskin print . one suede finish animal print . leather upper . lined heel . square toe . buckled ankle strap fastening.heel height 9.5 . 3.7″',
#  'ecru highheel shoes . striped upper maxi bow front . strap side around back ankle . kitten heels metallic detail combination materials . pointed toe . heel height . 2.3″',
#  'laceless sneakers . embossed detail upper . elastic side tabs slipping ease . white soles .',
#  'blue laceup sneakers . sixeyelet facing . microperforated detailing upper . contrast interior . contrast white soles slight central arch .',
#  'white plimsolls . facing six pairs eyelets . padded ankle detail greater comfort . red detail heel . blue tongue ankle padding . microperforations back centre . white soles blue outsoles .',
#  'white plimsolls . seven black metal eyelets eyestay . graphic print back . thick white soles . contrast twotone effect back sole . shiny finish heel tab .',
#  'laceup sneakers sixeyelet facing . blue mesh fabric upper contrast materials colours . trekkinginspired design . twotone chunky track sole .',
#  'white plimsollstyle sneakers . seveneyelet eyestay . soft heel design allows folded worn open . contrast red heel tab . white sole .',
#  'white laceup sneakers . sixeyelet facing . combination materials upper including perforated detailing toe mesh . white sole contrast caramelcoloured outsole . retroinspired design . back pull tab detail .',
#  'laceup plimsolls . microperforated detail upper . facing seven pairs eyelets .',
#  'white leather midheel mules . soft leather upper . woodeffect block heel . squarecut toe heel . heel height 6.3 . 2.4″',
#  'beige laceup sneakers faux nubuck finish . eighteyelet facing . overlaid patterns upper microperforated detailing instep .',
#  'gold midheel mules . crisscross straps front . squarecut toe . heel height . 3.1″',
#  'white sneakers . seven gold metal eyelets eyestay . graphic print back . thick white sole . contrast twotone red effect back sole . shiny finish heel tab .',
#  'plimsollstyle sneakers . seveneyelet eyestay . twotone model combining white upper black laces sole tongue heel tab . decorative lettering sole reading monochrome creating contrast effect .',
#  'white laceless sneakers . decorative braided embossing upper . white sole .',
#  'laceup plimsolls . seveneyelet eyestay . upper multiple pieces . microperforated detailing front upper . nubuckeffect finish . contrast white tongue heel tab sole .',
#  'snakeskin colour heeled sandals . vinyl strap uppers . fine clad mid heels square tip . animal print detailing sole heel . heel height 7.2 . 2.8″',
#  'sandals available various colours white coral . transparent vinyl strap front around heel . lined midheel . square toe . heel height . 3.1″',
#  'laceup sneakers combination colours materials upper including nylon split suede leather technical pieces . facing seven pairs eyelets . multicoloured track soles .',
#  'laceup sneakers contrast materials upper . seveneyelet facing . upper features different shades white combined caramelcoloured details . white sole caramelcoloured outsole .',
#  'multiway crossbody bag worn belt bag available black ecru . hardware detail foldover flap . two straps one chain strap one shoulder strap adjustable removable . gold metal hardware . interior lining . magnetic clasp closure.height length width . 8.6 5.9 3.9″',
#  'naturalcolour leather monk shoes . fastening two metal buckles . decorative seams upper . leather insoles lining .',
#  'oxford shoes . fiveeyelet eyestay . pointed toes . decorative seams upper . classic style .',
#  'oxford shoes . fiveeyelet eyestay . pointed toes . embossed detailing upper . classic style .',
#  'smart brown oxford shoes . fiveeyelet eyestay . decorative seams braidedeffect embossing upper . leather insole .',
#  'leather oxford brogues . fiveeyelet eyestay . broguing upper . pointed toe . leather insoles .',
#  'beige leather derby shoes split suede finish . soft design . foureyelet eyestay . pointed toes . decorative seams upper . leather insoles . classic style .',
#  'white laceup sneakers . contrast materials colours upper . animal print details sides heel . back pull tab . trims contrast colour back sole . chunky sole . sole height . 2.7″',
#  'rubbereffect sneakers . sockstyle design stretch fabric . embossed microperforated details upper . fiveeyelet facing . soles contrast white detail . back pull tab .',
#  'brown sporty oxford shoes . fiveeyelet facing . decorative seams upper . heel counter contrast colour . white soles coloured details .',
#  'leather shoes split suede finish . derby shoe construction . fiveeyelet facing . decorative pull tab back . sporty style . white soles .',
#  'leopard print ballerinas . animal print upper insole . animal print covered heel . toecap contrast colour.heel height 1.8 . 0.7″',
#  'black laceup sneakers six black metallic eyelets laces matte finish . featuring black laces white details white bumperstyle toe black white sole . ultra lightweight model urban style .',
#  'black leather loafers . decorative seams upper . leather lining insole . soft construction heel allowing worn open . metal appliqué instep .',
#  'flat gold sandals . thin braided straps crisscrossed instep . toe divider . sole height 1.1 . 0.4″',
#  'brown leather loafers twotone metallic appliqué instep . soft heel counter means worn slingback shoes . features leather insoles semipointed last . soft look classic style .',
#  'black loafers . penny strap detail instep . zara light split track sole maximum lightness comfort .',
#  'canvas loafers . decorative seams upper . fringed tassel trims instep contrast colour cord . classic style .',
#  'mini crossbody bag available several colours white pale pink . beaded exterior tortoiseshell kisslock frame . gold chain shoulder strap . lined interior . magnetic clasp closure . height length width . 7.4 6.6 1.5″',
#  'blue leather driving shoes split suede finish . embossed detailing . decorative bow instep . leather insoles . studded soles .',
#  'leather driving shoes split suede finish . bow detail instep topstitching upper leather insoles sole studs contrasting colour . available orange sky blue .',
#  'leather sandals available several colours . crisscross straps front.heel height 0.9 . 0.3″',
#  'black loafers . braided effect upper .',
#  'pool sandals . chunky rubber soles . contrastcoloured wide strap across instep .',
#  'slide pool sandals thick rubber soles . wide strap across instep zara logo .',
#  'beige leather espadrilles split suede finish . woven jute midsole . rubber sole .',
#  'pool slide sandals thick rubber soles . contrastingcoloured wide strap across instep .',
#  'sandals side fastening . vshaped straps around ankle wide strap instep . brown . flat soles .',
#  'ecru leather flat shoes . decorative piece instep . highcut vamp . sole height . 0.7″',
#  'gold highheel sandals . crisscross front strap . strap across instep . strap around back heel . lined high block heel platform sole . ankle strap fastening round buckle . heel height 11.3 . 4.4″',
#  'vinylcoated boots glitter star detail . side zip closure . warm interior lining fabric insole . pull tab slipping ease . track sole .',
#  'boots combination colours materials . contrast slogan detail . inner zip fastening . fabric lining . reinforced toecap contrast sole .',
#  'studded ankle boots elastic tabs slipping ease . 100 cotton insoles lining .',
#  'leather highheel ankle boots available tan ecru . leather upper . laces front . round block heel . zip fastening inside . heel height 6.5 . 2.5″',
#  'boots mickey mouse print patent finish . side zip adjustable laceup fastening . pull tab back slipping ease . fabric insoles lining .',
#  'fabric boots faux fur lining folddown detail . warm lining fabric insoles . contrastcoloured track soles .',
#  'fabric boots faux fur lining folddown detail . warm lining fabric insoles . contrastcoloured track soles .',
#  'black kitten heel shoes . patent finish upper . mesh detail sides back . vent inside . lined heel . pointed toe.due characteristics item suggest purchase one size down.heel height 4.5 . 1.7″',
#  'silver highheel shoes . asymmetric upper pleated detail front metallic finish . cutout detail side . contrastcoloured stiletto heel . pointed toe . heel height . 3.9″',
#  'backpack embossed grainy texture exterior . three zip pockets . inside main compartment pocket electronic devices laptops inches . mediumsized pocket back . two adjustable shoulder straps one top carry handle . padded back greater comfort use . smarturban look.height length width cm.available different colours .',
#  'multicoloured highheel sandals . iridescent upper multiple straps across front . covered stiletto heels . square toes . buckled ankle strap fastening . heel height 8.5 . 3.3″',
#  'multicoloured highheel sandals . animal print upper . straps across instep . lined high block heel . platform sole . buckled ankle strap fastening . heel height 13.5 . 5.3″',
#  'monochrome briefcasestyle bag . three zip pockets . main compartment inside pocket electronic devices laptops inches 13quot . also several inside pockets different sizes . two handles adjustable detachable shoulder strap . also attached handle suitcase using back strap . smart look.height length width 39.5 .',
#  'white laceup sneakers . combination materials upper . contrastcoloured details . animal print front heel . chunky sole raised effect . sole height . 2.3″',
#  'black sneakers . technical fabric upper elastic side tabs . contrastcoloured animal print sole back piece . pull tab slogan back . sole height 3.3 . 1.2″',
#  'sandcoloured leather sneakers . split suede upper . braided detail side . track sole contrast colours . laceup fastening . sole height 3.5 . 1.3″',
#  'black trainers . leather upper combination materials animal print . contrast colour chunky soles . laceup fastening . sole height . 1.9″',
#  'beige leather trainers . split suede upper . metallic trim back animal print . chunky sole contrast colour . laceup fastening contrast colour . sole height . 1.9″',
#  'white trainers animal print upper . back pull tab . laceup fastening metal eyelets.sole height 2.5 . 0.9″',
#  'mini city bag available lime coral . animal print exterior . metal clasp flap . top carry handle . chain shoulder strap . lined interior two compartments . magnetic clasp closure . height length width . 4.7 7.4 3.5″',
#  'black crossbody bag . tubular . double zip closure separate compartments . adjustable detachable strap.height length width 12.5 . 5.9 9.4 4.9″',
#  'velvet ballerinas . cross straps instep bejewelled buckles . 100 cotton lining fabric insole .',
#  'green slingback ballerinas . elastic strap ankle . pointed toes . heel height 2.1 . 0.8″',
#  'monochrome mini crossbody bag . three zip pockets . squarecut shape . adjustable strap . height length width 9.5 . 7.8 6.6 3.7″',
#  'black flat sandals . asymmetric upper . crisscross straps front . ankle strap fastening metal buckle . sole height 2.5 . 0.9″',
#  'transparent flat sandals . vinyl tubular straps upper . squarecut heel toe . sole height 1.5 . 0.5″',
#  'unicornshaped faux fur house slippers . adjustable elastic strap across instep .',
#  'beige tote bag . made natural materials . canvas exterior . contrastcoloured trims . handles slogan zip pulls . lined interior zip pocket . height length width 32.5 . 12.7 11.0 5.1″',
#  'flat mules contrast colours . made natural materials . bow detail contrast colour instep . pointed toe . jutelined sole . sole height 2.1 . 0.8″',
#  'smartphone protective case . rubberised edging helps protect mobile device . compatible iphone 11® 6.1.height length width 15.5 1.1 cm.not compatible wireless charging .',
#  'transparent vinyl mini crossbody bag white trims . featuring zip pocket flap pocket snapbutton fastening adjustable detachable shoulder strap detachable handle . urban design . height length width 15.5 . 7.8 6.1 1.5″',
#  'transparent green vinyl mini crossbody bag black trims . featuring zip pocket flap pocket snapbutton fastening adjustable detachable shoulder strap detachable handle . urban design . height length width 15.5 . 7.8 6.1 1.5″',
#  'basic card holder six card slots . also features central compartment storing notes andor . height length width . 2.7 4.3 0.3″',
#  'basic card holder six card slots . also features central compartment storing notes andor . height length width . 2.7 4.3 0.3″',
#  'card holder embossed finish . six card slots . features compartment centre . height length width . 3.1 3.9 0.3″',
#  'card holder embossed finish . six card slots . features compartment centre . height length width . 3.1 3.9 0.3″',
#  '100 cowhide leather flat sandals . adjustable hookandloop strap around back . 100 cowhide leather insoles . track soles .',
#  'black mountainstyle laceup boots featuring seven eyelets laces . includes padded detail ankle track sole .',
#  'brown mountainstyle laceup boots featuring seven eyelets laces . includes quilted detail ankle track sole .',
#  'brown split suede leather ankle boots . featuring elastic side tabs slipping ease sporty look . back pull tab detail . leather insoles . semipointed toes . urban style .',
#  'grey chelsea ankle boots . made leather split suede finish . elastic side panels back pull tabs slipping ease . welt soles .',
#  'black leather ankle boots nappa finish . decorative seams upper . two elastic side panels back pull tab slipping ease . straps metal buckles ankle . round toe . leather insole . zara light split track sole maximum lightness comfort .',
#  'black mountainstyle boots made cordura premium fabric hardwearing nylon resistant abrasion scratches slipping . featuring five eyelets laces two metallic appliqués making possible tie ankle black laces red details chunky black track sole . urban style .',
#  'beige leather ankle boots split suede finish . decorative seam details upper . two elastic side panels slipping ease . pull tab back . crepe track soles .',
#  'brown nappa leather ankle boots brushed effect . two elastic side panels slipping ease pull tab back . decorative seams upper slightly rounded last black soles leather insoles . classic style .',
#  'black leather ankle boots . two elastic side panels slipping ease . back pull tab . leather insoles . black track soles .',
#  'highheel red leather boots . leather upper . patent finish cracked effect . high leg . lined block heel . square cut toe . inside zip fastening . heel height 9.5 . 3.7″',
#  'matte black sporty rubberisedeffect ankle boots . decorative seams upper . two elastic side panels slipping ease . pull tabs back front . rounded toe . chunky black rubber sole .',
#  'black leather heeled boots . nappa leather upper . cowboy heel wedges . square pointed toe . side pull tabs . heel height . 3.1″calf width . 6.2″',
#  'beige contrast leather nylon laceup boots . mountainstyle . sixeyelet facing . leather insole . track sole .',
#  'highheel black leather boots . soft leather upper . overtheknee leg . lined geometric heel . almond toe . heel height . 3.9″calf width 22.5 . 8.8″',
#  'flat black leather boots . leather upper cracked finish . detachable saddle strap detail studs . inside zip . chunky covered heel . square toe . heel height 3.5 . 1.3″calf width 22.5 . 8.8″',
#  'leather heeled boots available different colours tan black . split suede upper . embroidered detail leg . cowboy heel . pointed toe . side pull tabs . heel height . 2.3″calf width . 7.0″',
#  'flat black boots . upper combination materials . high leg elastic fabric . pull tab back . track sole . heel height . 2.3″',
#  'burgundy laceup boots shiny finish . facing eight pairs eyelets zip inside back . zara light chunky track sole guarantees maximum lightness comfort . rounded toe .',
#  'leather highheel boots available black tan . leather upper . overtheknee slouchy leg leather . inside zip . woodeffect block heel.heel height 9.5 . 3.7″calf width 22.5 . 8.8″',
#  'black leather mountainstyle laceup boots . featuring eight eyelets faux fur interior lining greater warmth comfort decorative seam detail upper track sole .',
#  'black leather highheel boots . leather upper side saddle strap metal buckle . stiletto heel . pointed toe.airfit® . flexible technical latex foam insole designed offer greater comfort.heel height 8.5 . 3.3″calf width . 6.2″',
#  'leather heeled boots available different colours black lead grey . leather upper animal print texture . covered stiletto heel . pointed toe.blue collection . premium leather trims aegean blue soles metal emblem.heel height 9.5 . 3.7″calf width . 7.0″',
#  'flat black boots . high stretch leg . pull loop back . rounded toes . sole height . 1.5″',
#  'black velvet ankle boots . featuring elastic panels slipping ease . back pull tab . pointed toe . classic style soft design .',
#  'black sporty leather ankle boots split suede finish . two elastic side panels slipping ease . pull tab back . decorative seams upper . rounded toe . black sole . leather insole . track sole .',
#  'laceup high top sneakers . black . eighteyelet facing metallic gold appliqués . embossed faux reptileeffect entire upper . chunky black zara light sole maximum lightness comfort .',
#  'black midheel ankle boots . stretch fabric upper . pointed toes . matteeffect heels . heel height 6.5 . 2.5″',
#  'leather high heel ankle boots different colours black green . leather upper available different finishes nappa metallic animal print . stiletto heel . pointed toe . inside zip fastening.blue collection . premium leather trims aegean blue soles metal emblem.heel height . 3.9″',
#  'leather ankle boots heel available cream sky blue . featuring soft leather upper laces front lined wide flat heels square toes zip fastening inside . heel height 8.5 . 3.3″',
#  'black hightop sneakers laces . entire upper fabric except tongue inside piece made synthetic rubber . nine eyelets laces metal appliqués . trekking style sockstyle look ankle . includes pull tab back chunky track sole .',
#  'laceup hightop sneakers . white contrast black animal print reptile details . eighteyelet facing . padded ankles . golden piece welt . thick white zara light sole guarantees maximum lightness comfort .',
#  'black laceup hightop sneakers . featuring fabric upper leather detail . facing eight pairs eyelets . chunky sole black bumperstyle toe . extra white double laces available .',
#  'gold mid heel ankle boots . leather upper . lined thin heels . pointed toes . zip fastening inside . heel height . 2.7″',
#  'white hightop sneakers laceup fastening . functional exterior black zip side . black tongue lining . facing eight pairs eyelets . two choices laces black orange combine however like . slightly chunky white soles . ultra lightweight design . urban style .',
#  'black high heel ankle boots . stretch fabric upper . block heels track soles . heel height . 4.7″',
#  'black laceless sneakers made technical fabric . upper made single piece . sockstyle design . thick soles twopiece effect white black .',
#  'cowboystyle heeled ankle boots contrast colours . material upper elasticated back . cowboystyle mid heel . square toe . pull tab metallic stud detail back . heel height . 1.9″',
#  'white leather highheel mules . soft leather upper nappa finish . woodeffect block heel . pointed toe . back zip fastening . heel height . 3.1″',
#  'black high heel ankle boots . upper combined materials . technical fabric sides . wide heels track soles . rubberised piece toes . back pull tab . zip fastening front ring detail . heel height . 2.7″',
#  'black highheel ankle boots . technical fabric contrast materials upper . lined stiletto heel . pointed toe . laceup fastening metal eyelets front zip back . heel height 8.5 . 3.3″',
#  'black highheel ankle boots . perforated stretch fabric upper . lined stiletto heels . pointed toes . back pull tab contrast materials . laceup fastening front . heel height . 3.5″',
#  'black laceup hightop sneakers . eighteyelet facing . faux fur interior lining greater warmth comfort . decorative seam detail upper padded ankle . black sole .',
#  'black highheel ankle boots . animal embossing upper studs . cutout detail sides . block heel . square toe . back pull tab . ankle strap metal buckle closure.heel height 9.6 . 3.7″',
#  'black leather high heel ankle boots . rectangular block heel . back zip closure . heel height . 3.9″',
#  'leather midheel ankle boots available different colours white black snakeskin print . leather upper . rectangular block heel . square toe . inside zip fastening.due characteristics item suggest purchase one size down.heel height 5.2 . 2.0″',
#  'tan leather high heel ankle boots . stiletto heels . square toes . soles gold metal piece . zip fastening inside leg . heel height . 3.9″',
#  'black leather mid heel ankle boots . elastic side panels . metallic block heel . pointed toe.heel height . 2.7″',
#  'black heeled ankle boots . upper contrast materials . technical fabric shaft . mid block heel . pull tab back . heel height . 2.3″',
#  'black leather flat chelsea boots . elastic side tabs . back pull tab.heel height 2.4 . 0.9″',
#  'white leather ankle boots heel . featuring soft leather uppers welt detail around contour soles geometric block heels contrast colour zip fastening inside . heel height . 3.1″',
#  'flat black leather laceup ankle boots . leather upper . topstitching detail contrast colour around sole . back pull tab . chunky textured sole . metal buckle inside zip.sole height 4.5 . 1.7″',
#  'black leather midheel ankle boots . split suede upper topstitching detail . chunky midheel . square toe . back pull tab . inside zip fastening.due characteristics item suggest purchase one size down.heel height 4.5 . 1.7″',
#  'black leather midheel ankle boots . suede upper bow detail front . pointed toe . zip fastening inside.blue collection . premium leather trims aegean blue soles metal emblem.heel height . 2.7″',
#  'plain ankle boots combination colours . leather upper combined materials . rubberised piece front . padded ankle cuffs . back pull tab . chunky sole . laceup fastening metal eyelets.airfit® . flexible technical latex foam insole designed offer greater comfort.sole height 5.5 . 2.1″',
#  'corduroy hightop sneakers . adjustable laceup fastening . contrast printed pull tab back slipping ease . flexible rubber sole . cotton insole lining .',
#  'leather highheel shoes combination colours . animal print leather upper . stiletto heel . pointed toe . heel height 9.5 . 3.7″',
#  'black highheel shoes . mesh upper . elastic strap instep around back . stiletto heel . pointed toe . heel height . 3.9″',
#  'pink highheel shoes . glitter upper heel . lined high heel . pointed toe . heel height . 4.3″',
#  'heeled mules contrast colours . braided straps front . lined mid heel square toe . heel height 7.9 . 3.1″',
#  'laceup sneakers five eyelets laces . featuring combination colours materials including split suede leather mesh reflective details . includes pull tab front heel cap maxi sole .',
#  'black laceup sneakers white red details . facing six pairs eyelets . featuring combined materials upper including mesh technical pieces . front back pull tabs . chunky white sole black technical piece visible caramel outsole .',
#  'blue nylon plimsolls split suede brown pieces contrast orange line . seveneyelet metal facing . blue contrast heel tongue . white sole blue outsole .',
#  'white sneakers . seveneyelet eyestay . embossed detail side .',
#  'black mules heels . featuring gold metallic details front kitten heels pointed toes . heel height . 1.9″',
# ...
#  'cotton linen quilt . featuring plain design beige colour topstitching corners small embroidered lines . join life care fibre least sustainably grown european linen . sustainably grown european linen farmed using natural irrigation system genetically modified seeds defoliants . process waterfriendly helps protect environment .',
#  'washed cotton bedspread waffle effect .',
#  'washed cotton cushion cover waffle effect . cushion filling included .',
#  'grey cotton cushion cover . doublesided design quilted check velvet one side washed cotton . cushion filling included .',
#  'light gray faded finish cotton quilt . striped dyed thread design one sides .',
#  'light gray washed cotton throw pillow . striped dyed thread design one sides . pillow filling included .',
#  'washed effect linen cotton quilt . stitching detail around edge tassels corners .',
#  'washed effect linen cotton cushion cover . stitching detail around edge tassels corners . cushion filling included .',
#  'blanket featuring herringbone design fringed edges .',
#  'floral freshness fragrance seduces lovers floral notes . bouquet wild flowers featuring intoxicating jasmine delicate freshness lily valley . main aromatic notes jasmine lily valley cucumber . zara home home spray fragrance developed home available spray aerosol form . need couple doses fill entire room scent . recommend applying fabric accessories home avoiding painted varnished surfaces .',
#  'linen cushion cover featuring striped print . zip fastening . cushion filling included .',
#  'spray air freshener easily quickly perfume room.a fusion sensuality vanilla citrus floral notes sweet mellow fragrance varied scents hit location . addictive intoxicating sure captivate . perfect creating warm inviting atmosphere . main aromatic notes praline milk musk citrus fruits vanilla . lasts approximately months .',
#  'spray air freshener easily quickly perfume room.energy vigor . deep fragrance personality light touch bergamot draws woody ylangylang notes sensuality sandalwood . oneway ticket east exotic . main aromatic notes bergamot clove cardamom ylangylang flower jasmine cedarwood sandalwood . lasts approximately months .',
#  'furry cushion cover . zip fastening . cushion filling included .',
#  'cotton chenille cushion cover . cushion filling included .',
#  'spray air freshener easily quickly fragrance room.feminine unique . perfect balance fruit white flowers . peach orange gardenia ... defined fragrance full energy strength . despite sustained scent elegance bestows discreet refined presence . femininity turned fragrance . main aromatic notes gardenia orange blossom violet peach coconut lasts approximately months .',
#  'spray air freshener easily quickly perfume room.the warmth tempting smoky hint patchouli wood create woody oriental captivating fragrance reminiscent secluded part far east . notes beckon wind relax disconnect . breathe enjoy . oriental light . main aromatic notes musk wood pachouli sandalwood bergamot atlas cedar cistus . lasts approximately months .',
#  'cotton cushion cover featuring checked print .',
#  'soft monochrome fleece blanket .',
#  'fabric freshener spray . alcoholfree formula means used fabric.sweet romantic fresh wild . versatile fragrance changes depending time day happen enjoying . dont let name fool trace ginger notes . lily base exotic touches musk cinnamon . main aromatic notes lily lily valley heliotrope jasmine cinnamon musk .',
#  'fabric freshener spray . alcoholfree formula means used fabric.feminine unique . perfect balance fruit white flowers . peach orange gardenia ... defined fragrance full energy strength . despite sustained scent elegance bestows discreet refined presence . femininity turned fragrance . main aromatic notes gardenia orange blossom violet peach coconut',
#  'fabric freshener spray . alcoholfree formula means used fabric.imagine smell freshcut grass walking barefoot garden sitting shade tree read book . muchneeded dose vitamin nature purest form home . green herbs freshest fragrance zara home . main aromatic notes fresh cut grass floral bouquet lily valley .',
#  'coloured chenille cotton blanket fringing .',
#  'fabric freshener spray . alcoholfree formula means used fabric.the quality tempting smoky hint patchouli wood create woody oriental captivating fragrance reminiscent secluded part far east . notes beckon wind relax disconnect . breathe enjoy . oriental light . main aromatic notes musk wood pachouli sandalwood bergamot atlas cedar cistus .',
#  'scented cards wardrobes drawers . energy vigour . deep fragrance personality light touch bergamot draws woody ylangylang notes sensuality sandalwood . oneway ticket orient exotic . main aromatic notes bergamot clove cardamom ylangylang flower jasmine cedarwood sandalwood . depending location conditions exposed may last one three months .',
#  'scented cards drawers wardrobes . include hanging loops sold packs 3.aroma ginger lily purely floral fragrance sweet subtle hints cinnamon.lasts months.this duration may vary depending room temperature humidity conditions.notescinnamon almond blossom lilac lilywhite musk heliotrope',
#  'scented cards wardrobes drawers . feminine unique . perfect balance fruit white flowers . peach orange gardenia ... defined fragrance full energy strength . despite sustained scent elegance bestows discreet refined presence . femininity turned fragrance . main aromatic notes gardenia orange blossom violet peach coconut depending location conditions exposed may last one three months .',
#  'scented cards drawers wardrobes . include hanging loops sold packs 3.aroma green herbs fragrance evokes breeze field freshly cut grass authentic connection nature.lasts months.this duration may vary depending room temperature humidity conditions.noteswet grass petitgraindaisy lilyartemisia neroli',
#  'scented cards wardrobes drawers . quality tempting smoky hint patchouli wood create woody oriental captivating fragrance reminiscent secluded part far east . notes beckon wind relax disconnect . breathe enjoy . oriental light . main aromatic notes musk wood pachouli sandalwood bergamot atlas cedar cistus . depending location conditions exposed may last one three months .',
#  'linen throw pillow zip fastening . pillow filling included .',
#  'wool cotton blanket . boasting multicoloured design floral geometric motifs decorative fringing .',
#  'faux fur cushion cover zip fastening . cushion filling included .',
#  'cotton muslin bedspread contrast check pattern .',
#  'cotton muslin throw pillow contrast check pattern . pillow filling included .',
#  'wool acrylic blanket contrast check design .',
#  '100 vegetable wax scented candle two wicks . comes cylindrical glass tumbler.sweet romantic fresh wild . versatile fragrance changes depending time day happen enjoying . dont let name fool trace ginger notes . lily base exotic touches musk cinnamon . main aromatic notes lily lily valley heliotrope jasmine cinnamon musk . lasts approximately hours . instructions use always place candle heatresistant surfaces away heaters hot surfaces . light candle rooms children pets . always keep lit candle vertical position wax burns evenly . snuff allow wax cool using . keep wick cut wax optimum burning . keep wax clear residue . always keep candle away curtains ventilation air vents . use one candle time leave space . snuff candle four hours uninterrupted use never leave burning unattended room . always use candle snuffer . snuff candle burns way .',
#  'blanket featuring multicolored bands contrasting thin stripes .',
#  'deep complex fragrance illuminated bergamot ylangylang sensual notes sandalwood transporting exotic east . main aromatic notes bergamot clove cardamom ylangylang flower jasmine cedarwood sandalwood . liquid hand soap transparent container dispenser . contains aloe vera glycerine extracts help hydrate soften skin . made .',
#  'blanket multicoloured geometric shapes .',
#  'ginger lily species tropical lily originating india related ginger root except name . took inspiration tropical lily create captivating floral fragrance invokes recentlycut bunch lilies exotic touch musk cinnamon notes . main aromatic notes lily heliotrope jasmine cinnamon musk . liquid hand soap transparent container dispenser . contains aloe vera glycerine extracts help hydrate soften skin . made .',
#  'wool cushion cover featuring checked pattern . zip fastening . cushion filling included .',
#  'notes lively fragrance invite enter garden juicy hints peach orange blend subtly scent white gardenia flower undisputed protagonist . main aromatic notes gardenia orange blossom violet peach coconut . liquid hand soap transparent container dispenser . contains aloe vera glycerine extracts help hydrate soften skin . made .',
#  'nature home . sensation behind fragrance natural vigour freshlycut grass feminine touch bouquet wild flowers everdelicate purity lily valley create clean clear ambience . main aromatic notes fresh cut grass floral bouquet lily valley . liquid hand soap transparent container dispenser . contains aloe vera glycerine extracts help hydrate soften skin . made .',
#  'smoked wood wraps mysterious veil incense cistus patchouli notes amber revealing essence oriental wood . main aromatic notes musk wood patchouli sandalwood bergamot atlas cedar cistus . liquid hand soap transparent container dispenser . contains aloe vera glycerine extracts help hydrate soften skin . made .',
#  'oyster white microfiber quilt . quilted design upholstered effect .',
#  'oyster white microfibre cushion cover . quilted design upholstered effect . cushion filling included .',
#  'deep complex fragrance illuminated bergamot ylangylang sensual notes sandalwood transporting exotic east . main aromatic notes bergamot clove cardamom ylangylang flower jasmine cedarwood sandalwood . body lotion transparent container dispenser . easy absorption leaves skin smooth hydrated light touch fragrance .',
#  'blanket geometric motifs different colours .',
#  'notes lively fragrance invite enter garden juicy hints peach orange blend subtly scent white gardenia flower undisputed protagonist . main aromatic notes gardenia orange blossom violet peach coconut . body lotion transparent container dispenser . easy absorption leaves skin smooth hydrated light touch fragrance .',
#  'blanket twotone design .',
#  'nature home . sensation behind fragrance natural vigour freshlycut grass feminine touch bouquet wild flowers everdelicate purity lily valley create clean clear ambience . main aromatic notes fresh cut grass floral bouquet lily valley . body lotion transparent container dispenser . easy absorption leaves skin smooth hydrated light touch fragrance .',
#  'smoked wood wraps mysterious veil incense cistus patchouli notes amber revealing essence oriental wood . main aromatic notes musk wood patchouli sandalwood bergamot atlas cedar cistus . body lotion transparent container dispenser . easy absorption leaves skin smooth hydrated light touch fragrance .',
#  'childrens white lacquered wooden bench natural wooden drawers cotton rope knobs . two furniture pieces design available match .',
#  'box metal edges glass sides .',
#  'cushion featuring backstitching . cushion filling included .',
#  'cotton cushion cover rugstyle design zip fastening . cushion filling included .',
#  'cotton cushion cover zip fastening . cushion filling included .',
#  'cotton linen cushion cover placement stripe print zip fastening . cushion filling included .',
#  'rectangular cushion cover striped design zip fastening . cushion filling included .',
#  'blanket featuring lined design contrast color motifs .',
#  'patterned wool cushion cover zip fastening . cushion filling included .',
#  'doublesided blanket check design one side fleece .',
#  'decorative cushion tartan print side zip fastening . cushion filling included .',
#  'cushion cover tartan print dark tones .',
#  'rectangular christmas cushion featuring dear santa slogan .',
#  '100 cotton towel oyster white . featuring geometric jacquard border metallic thread detailing .',
#  '100 cotton towel oyster white . featuring geometric jacquard border metallic thread detailing .',
#  'lacquered wood hanger bar hang trousers .',
#  'lacquered wood hanger clips hanging skirts dresses trousers .',
#  'aluminum hanger wooden bar clips.sold set .',
#  'aluminum hanger wooden bar suitable hanging kinds clothes.sold set .',
#  'faux fur blanket super soft feel .',
#  'set metal skirt hangers .',
#  'padded iron hanger lined cotton linen featuring iron hook tassel detail . sold packs .',
#  'metal hanger ideal tshirts sweaters coats shirts notches ends hang garments ties .',
#  'oversized cotton jersey tshirt round neck short sleeves .',
#  'straightleg cotton jersey trousers drawstring waist .',
#  'long cotton jersey dressing gown pockets belt fastening .',
#  'short sleeve cotton jersey dress round neck .',
#  'cotton jersey shirt vneck pocket .',
#  'leggings pockets .',
#  'flannel trousers tartan print front pockets elastic waist .',
#  'flannel eye mask tartan print grey interior elastic .',
#  'flannel shirt tartan print . shirtstyle long sleeves pocket .',
#  'mens flannel set pyjamas tartan print . shirtstyle long sleeves pocket .',
#  'plain washed linen fitted sheet 160 gm2 . adjustable elastic corners mattress 11.8 thick .',
#  'lamp featuring resin base fabric lampshade . light bulb included . recommended max . 60w bulb . external cable cord lamp gets damaged must replaced qualified technician order avoid risk . socket e27 markets e26 mexico japan korea .',
#  'cotton towel featuring border multicoloured stripe design . 480 gsm .',
#  'cotton pouffe strap pocket .',
#  'lamp featuring wooden base glass lampshade . light bulb included . recommended max . 60w bulb . external cable cord lamp gets damaged must replaced qualified technician order avoid risk . socket e27 markets e26 mexico japan korea .',
#  'methacrylate side table ushaped structure storage space .',
#  'square tray faceted mirror design . two sides holes serve handles .',
#  'night set comprising bottle capacity 100 . tumbler transparent glass bubbleeffect . pieces glow dark .',
#  'textured faux fur rug .',
#  'symmetrical wall mirror gold frame .',
#  'scoredeffect rug .',
#  'thick transparent glass tumbler faceted design . capacity .',
#  'thick transparent glass soft drink tumbler faceted design . capacity .',
#  'wine glass circular base.capacity .',
#  'round woven basket side handle . perfect using bread basket decorative piece storage .',
#  'cotton rug multicoloured geometric motifs .',
#  'cream wool jute mix rug beige cream stripes .',
#  'patchworkeffect rug .',
#  'wireless plastic lamp bamboo handle led light bulb battery recharged using usb .',
#  'basket handles triangle pattern .',
#  'rectangular wood side table cross metal legs .',
#  'circular wooden jewellery box featuring two trays compartments linenlined interior .',
#  'rectangular wooden jewellery box featuring two trays compartments linenlined interior .',
#  'table mirror wooden frame .',
#  'standup mirror black iron base option tilt .',
#  'black lacquered metal lamp . light bulb included . recommended max . 60w bulb . external cable cord lamp gets damaged must replaced qualified technician order avoid risk . socket e14 markets e26 mexico japan korea .',
#  'fleeceupholstered armchair .',
#  'cotton towel striped design fringed edges.grammage 460 gm2 .',
#  'doublesided cotton towel.grammage 460 gm2 .',
#  'doublesided cotton towel . sold pack 2.grammage 460 gm2 .',
#  'cotton towel tassels edges . sold pack 3.grammage 460 gm2 .',
#  'cotton towel tassels edges.grammage 460 gm2 .',
#  'cotton towel lined band edges.grammage 460 gm2 .',
#  'smallest table measures cmthe largest table measures cmset two nesting tables featuring golden structure seamed white marble top . due nature product marble seams colour may vary.not suitable outdoor use .',
#  'cotton towel crochet border edges.grammage 480 gm2 .',
#  'basket featuring metal structure covered resilient paper round base linen cotton lining.removable washable fabric lining .',
#  ...]

# %%
# Save the cleaned and tokenize text in the dataframe
data['description']=cleaned_text

# %%
data_path +'\\cl_stopw_'+os.path.splitext(test_filename)[0]+'.csv'
# Out:
# 'C:\\Users\\edumu\\Google Drive\\datasets\\SpainAI NLP\\cl_stopw_test_descriptions.csv'

# %%
data
# Out:
#                                             description
# 0     knit midi dress vneckline straps matching lace...
# 1     loosefitting dress round neckline long sleeves...
# 2     nautical cap peak.this item must returned orig...
# 3     nautical cap peak . adjustable inner strap det...
# 4     nautical cap side button detail.this item must...
# ...                                                 ...
# 1436  striped print cotton cushion cover . cushion f...
# 1437        rectangular cushion featuring gnome print .
# 1438  cotton jersey eye mask featuring elastic band ...
# 1439  padded chipboard hanger featuring iron hook pa...
# 1440  iron hanger suitable hanging kinds clothes . u...
#
# [1441 rows x 1 columns]

# %%
# Create a file with the whole dataset cleaned
data.to_csv(data_path +'\\cl_stopw_'+os.path.splitext(test_filename)[0]+'.csv', index=False)

# %% [markdown]
# ### Checking the files created

# %%
train_df=pd.read_csv("data/news_summary_train.csv")
print('Train Length: ',len(train_df))
train_df.head(20)
# Out:
# Train Length:  83606
#                                             headlines  \
# 0   Paytm raises $1.4 billion from SoftBank in lar...
# 1   Petrol price cut by â¹1.12 per litre as daily...
# 2   Army plans to deploy women officers for cyber ...
# 3   Uday Chopra confirms YRF will produce Jessica ...
# 4   Mulayam Yadav to contest 2019 polls from Mainp...
# 5   I am so excited to play under Virat Kohli's ca...
# 6   Twitter reacts to women-only screening of Wond...
# 7   Apple to hire engineer with psychology backgro...
# 8   Railway Board Chairman resigns after 2 derailm...
# 9              Who is billionaire Radhakishan Damani?
# 10  Flyers told to jump onto tarmac after threaten...
# 11  My mother asked me how could I do this to Hard...
# 12  4 years since Beckham announced his retirement...
# 13  We've gone through so many CTOs, it's a joke: ...
# 14  People in the film industry call me a bull: Ar...
# 15  Govt proposes airing public interest messages ...
# 16  Maybe true: 'Taarak Mehta Ka...' producer on D...
# 17  Which teams have qualified for 2018 FIFA World...
# 18  Karnataka govt plans 1 lakh houses for poor in...
# 19  Pak SC bars Nawaz Sharif from holding public o...
#
#                                                  text
# 0   Digital payments startup Paytm has raised $1.4...
# 1   Oil companies on Thursday reduced the petrol p...
# 2   The Indian Army has announced plans to deploy ...
# 3   Yash Raj Films CEO Uday Chopra has confirmed t...
# 4   Senior Samajwadi Party leader Ram Gopal Yadav ...
# 5   Batsman Shubman Gill, who has been included in...
# 6   Reacting to Texas' The Alamo Drafthouse theatr...
# 7   Apple is hiring a software engineer with psych...
# 8   The Chairman of the Railway Board, Ashok Mitta...
# 9   Radhakishan Damani is the 61-year-old billiona...
# 10  Passengers were told to "jump" onto the tarmac...
# 11  After Hardik Pandya and KL Rahul were suspende...
# 12  Former England captain David Beckham announced...
# 13  When asked about the difficulties faced while ...
# 14  Actor Arjun Rampal has said that he feels like...
# 15  The Information and Broadcasting (I&B) Ministr...
# 16  'Taarak Mehta Ka Ooltah Chashmah' producer Asi...
# 17  France, who are among the six European teams t...
# 18  Karnataka Chief Minister Siddaramaiah will soo...
# 19  The Pakistan Supreme Court on Friday disqualif...

# %%
valid_df=pd.read_csv("data/news_summary_valid.csv")
print('Valid Length: ',len(valid_df))
valid_df.head(20)
# Out:
# Valid Length:  14754
#                                             headlines  \
# 0   Govt forms SIT in Ryan murder case, CBSE seeks...
# 1   Indrani asks for furniture, jewellery in divor...
# 2   ED raids 35 premises of Nirav Modi, â¹550-cr ...
# 3   Japan admits 1st death from 2011 Fukushima nuc...
# 4   An entire village in Germany is being auctione...
# 5   Man Utd luckiest PL team, Liverpool unluckiest...
# 6   Raina overtakes Kohli to become IPL's top run-...
# 7   Mumbai housing society saves â¹2 lakh a month...
# 8   NASA launches two Antarctic flights from two c...
# 9   Pentagon slammed for wasting â¹180 cr on Afgh...
# 10  Muslims pray outside White House in protest ov...
# 11  Swimming, water sports on Goa beaches closed o...
# 12  I disagree with the term 'item song': Katrina ...
# 13  You can hide marriage, not pregnancy: Anushka ...
# 14  Will remove your hand from cycle handle: Akhil...
# 15  Finch scores fastest fifty for GL in 7-wicket ...
# 16  Mumbai cyclone alert a rumour, clarifies civic...
# 17  'Ball of the Century' like delivery bowled in ...
# 18  I'm not a Muslim & I've to be woken up by Azaa...
# 19  7-year-old girl raped on neighbour's terrace i...
#
#                                                  text
# 0   The HRD Ministry has formed a three-member Spe...
# 1   In a letter written from jail, Sheena Bora mur...
# 2   The Enforcement Directorate (ED) on Friday con...
# 3   Japan has acknowledged for the first time that...
# 4   An entire village in Germany is being auctione...
# 5   Manchester United were the luckiest team while...
# 6   CSK's Suresh Raina overtook RCB captain Virat ...
# 7   Residents of a 20-storey housing complex in Ka...
# 8   For the first time in its nine years of operat...
# 9   US Defence Secretary James Mattis has criticis...
# 10  Hundreds of Muslims prayed outside the White H...
# 11  Swimming and water sports across beaches in Go...
# 12  Actress Katrina Kaif has said she disagrees wi...
# 13  Anushka Sharma, while denying rumours of her p...
# 14  Former Uttar Pradesh CM Akhilesh Yadav has acc...
# 15  Gujarat Lions defeated Royal Challengers Banga...
# 16  After messages about a cyclone in Mumbai went ...
# 17  Australian women's team spinner Amanda-Jade We...
# 18  Singer Sonu Nigam on Monday took to Twitter to...
# 19  A seven-year-old girl was allegedly raped by a...

# %%
train_df['text'][0]
# Out:
# "Digital payments startup Paytm has raised $1.4 billion from SoftBank in India's largest funding round. This is also SoftBank's biggest investment in the Indian startup ecosystem till date. The latest investment by SoftBank will value Paytm at around $8 billion, up from its valuation of $4.8 billion in August 2016. "
